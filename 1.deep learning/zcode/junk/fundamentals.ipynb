# %% [markdown]
# # Step 1: Neuron (inputs, weights, bias)

# %% [markdown]
# Suppose we’re predicting whether a student passes (1) or fails (0) an exam based on two features:
#
# x1 = hours studied
# x2 = number of practice tests taken
#
# We assign:
# Inputs:
# x1=2,
# x2=3
